# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("loan_approval_dataset.csv")

# %%
df.head()
# Out:
#    loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0        1                 2       Graduate             No        9600000
# 1        2                 0   Not Graduate            Yes        4100000
# 2        3                 3       Graduate             No        9100000
# 3        4                 3       Graduate             No        8200000
# 4        5                 5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1   no_of_dependents           4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.describe()
# Out:
#            loan_id  no_of_dependents   income_annum   loan_amount  \
# count  4269.000000       4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000          2.498712   5.059124e+06  1.513345e+07
# std    1232.498479          1.695910   2.806840e+06  9.043363e+06
# min       1.000000          0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000          1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000          3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000          4.000000   7.500000e+06  2.150000e+07
# max    4269.000000          5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# 25%       6.000000    453.000000               2.200000e+06
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                      0
# no_of_dependents             0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
x = pd.DataFrame(df.iloc[:,1:-1])
y = pd.DataFrame(df.iloc[:,-1])

# %%
x.head()
# Out:
#    no_of_dependents      education  self_employed   income_annum  \
# 0                 2       Graduate             No        9600000
# 1                 0   Not Graduate            Yes        4100000
# 2                 3       Graduate             No        9100000
# 3                 3       Graduate             No        8200000
# 4                 5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value
# 0                  17600000              22700000            8000000
# ...

# %%
y.head()
# Out:
#   loan_status
# 0    Approved
# 1    Rejected
# 2    Rejected
# 3    Rejected
# 4    Rejected

# %%
df[" loan_status"].value_counts()
# Out:
#  loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df[" loan_status"] = le.fit_transform(df[" loan_status"])
df[" education"] = le.fit_transform(df[" education"])
df[" self_employed"] = le.fit_transform(df[" self_employed"])

# %%
df.head()
# Out:
#    loan_id  no_of_dependents   education   self_employed   income_annum  \
# 0        1                 2           0               0        9600000
# 1        2                 0           1               1        4100000
# 2        3                 3           0               0        9100000
# 3        4                 3           0               0        8200000
# 4        5                 5           1               1        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
x = pd.DataFrame(df.iloc[:,1:-1])
y = pd.DataFrame(df.iloc[:,-1])

# %%
x.head()
# Out:
#    no_of_dependents   education   self_employed   income_annum   loan_amount  \
# 0                 2           0               0        9600000      29900000
# 1                 0           1               1        4100000      12200000
# 2                 3           0               0        9100000      29700000
# 3                 3           0               0        8200000      30700000
# 4                 5           1               1        9800000      24200000
#
#     loan_term   cibil_score   residential_assets_value  \
# 0          12           778                    2400000
# 1           8           417                    2700000
# 2          20           506                    7100000
# 3           8           467                   18200000
# 4          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value
# 0                  17600000              22700000            8000000
# ...

# %%
y.head()
# Out:
#    loan_status
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
print(le.classes_)
# Out:
# [' No' ' Yes']

# %%
features = df.columns[1:-1]
print(features)
# Out:
# Index(['no_of_dependents', ' education', ' self_employed', ' income_annum',
#        ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value'],
#       dtype='object')

# %%
# for i, classes in enumerate(features):
#     plt.figure(figsize=(12,8), dpi=200)
#     sns.scatterplot(df, x=classes, y=" loan_status")

# plt.tight_layout(pad=3)
# plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(criterion="entropy", random_state=42)

rf.fit(x_train, y_train)
# Out:
# c:\Users\LENOVO\anaconda3\envs\mdm\lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(criterion='entropy', random_state=42)

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn import metrics

con_mat_rf = metrics.confusion_matrix(y_pred, y_test)
print(con_mat_rf)

print("Accuracy score=", metrics.accuracy_score(y_test, y_pred))
print("F1 score=", metrics.f1_score(y_test, y_pred, average="macro"))
# Out:
# [[528  12]
#  [  8 306]]
# Accuracy score= 0.9765807962529274
# F1 score= 0.9748835348924757

# %%
from sklearn import tree

dt = tree.DecisionTreeClassifier(criterion="entropy", random_state=42)

dt.fit(x_train, y_train)

y_pred_dt = rf.predict(x_test)

# %%
from sklearn import metrics

con_mat_dt = metrics.confusion_matrix(y_pred_dt, y_test)
print(con_mat_dt)

print("Accuracy score=", metrics.accuracy_score(y_test, y_pred_dt))
print("F1 score=", metrics.f1_score(y_test, y_pred_dt, average="macro"))
# Out:
# [[528  12]
#  [  8 306]]
# Accuracy score= 0.9765807962529274
# F1 score= 0.9748835348924757
